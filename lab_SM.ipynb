# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
data_path = "./data"

df = pd.read_csv(f"{data_path}/Small-diameter-flow.csv")
df
# Out:
#      Unnamed: 0       Flow  Kinematic  Geometric   Inertial  Observer
# 0             0 -17.047687  -0.584344  -6.896327 -14.323560       0.0
# 1             1 -17.043179  -0.584344  -6.896327 -14.323560       0.0
# 2             2 -17.043179  -0.584344  -6.896327 -14.323560       0.0
# 3             3 -11.182193   1.242506  -5.069476 -11.583284       0.0
# 4             4 -11.184430   1.242506  -5.069476 -11.583284       0.0
# ..          ...        ...        ...        ...        ...       ...
# 193         193 -11.549945   0.676618  -5.141828 -11.985050       1.0
# 194         194 -11.588558   0.676618  -5.141828 -11.985050       1.0
# 195         195 -11.575993   0.604644  -5.141828 -11.985050       1.0
# 196         196 -11.548646   0.604644  -5.141828 -11.985050       1.0
# 197         197 -11.595403   0.604644  -5.141828 -11.985050       1.0
#
# [198 rows x 6 columns]

# %%
df.drop(columns="Unnamed: 0", inplace=True)
df.describe()
# Out:
#              Flow   Kinematic   Geometric    Inertial    Observer
# count  198.000000  198.000000  198.000000  198.000000  198.000000
# mean   -12.106517    0.305508   -5.382368  -12.764538    0.439394
# std      1.469045    0.485702    0.451501    0.767815    0.497571
# min    -17.047687   -0.698878   -6.896327  -14.332156    0.000000
# 25%    -11.654464    0.179341   -5.206650  -12.813898    0.000000
# 50%    -11.512967    0.375271   -5.203007  -12.623005    0.000000
# 75%    -11.397828    0.604644   -5.202436  -12.453012    1.000000
# max    -11.095609    1.242506   -5.069476  -11.583284    1.000000

# %%
plt.plot(x = df["Flow"])
# sns.scatterplot(data=df["Flow"])

# %%
sns.pairplot(df)

# %%
plt.scatter(df["Flow"], df["Kinematic"])
